# %%
import networkx as nx
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import timedelta
import pickle as pk
import matplotlib.pyplot as plt

# database connection
def get_db_connection():
    engine = create_engine('postgresql://postgres:1234@localhost:5432/june')
    return engine.connect()

# Extract data from database
def extract_forum_data(forum_id, min_post_length, classification_threshold):
    conn = get_db_connection()
    query = """
    SELECT posts.user_id, posts.topic_id, posts.dateadded_post, LENGTH(posts.content_post) AS post_length, 
           topics.dateadded_topic AS thread_start_date, topics.classification2_topic
    FROM posts
    INNER JOIN topics ON posts.topic_id = topics.topic_id
    WHERE topics.forum_id = %s AND topics.classification2_topic > %s
    """
    df = pd.read_sql(query, conn, params=(forum_id, classification_threshold))
    conn.close()
    
    # Convert post and thread start dates to datetime
    df['dateadded_post'] = pd.to_datetime(df['dateadded_post'], utc=True)
    df['thread_start_date'] = pd.to_datetime(df['thread_start_date'], utc=True)
    
    # Filter posts by minimum length
    df = df[df['post_length'] > min_post_length]
    
    return df

# Create the network for the forum
def make_net(forum_id, time_window_days, min_post_length, classification_threshold):
    user_data = extract_forum_data(forum_id, min_post_length, classification_threshold)
    X = nx.DiGraph()  
    
    # Group by topic for per thread interactions
    for topic_id, group in user_data.groupby('topic_id'):
        first_post_date = group['dateadded_post'].min()
        # Filter posts within the time window from the first post date
        filtered_group = group[group['dateadded_post'] <= first_post_date + timedelta(days=time_window_days)]
        
        users = filtered_group['user_id'].to_numpy()

        X.add_nodes_from(users)  # Add users as nodes

        # Add directed edges based on user interactions
        for i in range(len(users) - 1):
            for j in range(i + 1, len(users)):
                if users[i] != users[j]:
                    if X.has_edge(users[i], users[j]):
                        # If the edge exists, weight++
                        X[users[i]][users[j]]['weight'] += 1
                    else:
                        X.add_edge(users[i], users[j], weight=1)

    return X

# Save the network
def save_net(N, forum_id):
    path = f"pickleX{forum_id}.p"
    with open(path, 'wb') as f:
        pk.dump(N, f)
    print(f'Pickle file saved for Forum {forum_id} at {path}...')
    return path

# Load the network from a pickle file
def get_net(path):
    with open(path, 'rb') as f:
        load = pk.load(f)
    return load

# Visualize the created network
def visualize_network(G):
    plt.figure(figsize=(12, 12)) 
    pos = nx.spring_layout(G)  # the spring layout
    nx.draw(G, pos, with_labels=True, node_size=500, node_color="skyblue", font_size=10, font_weight="bold", edge_color="gray")
    
    # Draw edge labels (weights)
    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    plt.title("Network Visualization")
    plt.show()


# Parameters for network creation
forum_id = 8
time_window_days = 30
min_post_length = 2
classification_threshold = 0.5

# Create the network and save it
network = make_net(forum_id, time_window_days, min_post_length, classification_threshold)
save_net(network, forum_id)

# Visualize the network
visualize_network(network)
# Out:
# Pickle file saved for Forum 8 at pickleX8.p...

# %% [markdown]
# # Feature Extraction

# %%
import networkx as nx
import pandas as pd
import numpy as np
import community
import datetime as dt

# Global variables for centrality measures
X = None
C = None
UX = None
PR = None

# %% [markdown]
# # Alpha Beta Graph

# %%
def get_early_adopters_from_db(forum_id, alpha, beta, classification_threshold, content_length_threshold=0, min_posts=1, min_threads=1):
    conn = get_db_connection()
    query = """
    SELECT DISTINCT posts.topic_id, posts.user_id, posts.dateadded_post, LENGTH(posts.content_post) AS content_length, topics.classification2_topic
    FROM posts
    INNER JOIN topics ON posts.topic_id = topics.topic_id
    WHERE topics.forum_id = %s AND topics.classification2_topic > %s
    """
    df = pd.read_sql(query, conn, params=(forum_id, classification_threshold))
    conn.close()

    # Convert dateadded_post to datetime and ensure UTC
    df['dateadded_post'] = pd.to_datetime(df['dateadded_post'], utc=True)

    # Filter topics with content length greater than the specified threshold
    df = df[df['content_length'] > content_length_threshold]

    # Filter users based on the minimum number of posts
    user_post_counts = df.groupby('user_id').size()
    valid_users = user_post_counts[user_post_counts >= min_posts].index
    df = df[df['user_id'].isin(valid_users)]

    # Filter threads based on the minimum number of threads by users
    user_thread_counts = df.groupby(['user_id', 'topic_id']).size().groupby('user_id').size()
    valid_users_by_threads = user_thread_counts[user_thread_counts >= min_threads].index
    df = df[df['user_id'].isin(valid_users_by_threads)]

    # Ensure unique commenters per topic
    df = df.drop_duplicates(subset=['topic_id', 'user_id'])

    # Process the dataframe to get csc, ncsc, tcsc, tncsc
    csc = {}
    ncsc = {}
    tcsc = {}
    tncsc = {}

    for topic_id, group in df.groupby('topic_id'):
        sorted_group = group.sort_values(by='dateadded_post')
        csc[topic_id] = sorted_group['user_id'].tolist()[:int(alpha)]
        ncsc[topic_id] = sorted_group['user_id'].tolist()[:int(beta)]
        tcsc[topic_id] = sorted_group['dateadded_post'].tolist()[:int(alpha)]
        tncsc[topic_id] = sorted_group['dateadded_post'].tolist()[:int(beta)]

    return csc, ncsc, tcsc, tncsc

# %% [markdown]
# # DB structure

# %%
def show_tables():
    conn = get_db_connection()
    query = """
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public';
    """
    df = pd.read_sql(query, conn)
    conn.close()
    return df

def show_columns(table_name):
    conn = get_db_connection()
    query = f"""
    SELECT column_name, data_type 
    FROM information_schema.columns 
    WHERE table_name = '{table_name}';
    """
    df = pd.read_sql(query, conn)
    conn.close()
    return df

def preview_table(table_name, limit=10):
    conn = get_db_connection()
    query = f"SELECT * FROM {table_name} LIMIT {limit};"
    df = pd.read_sql(query, conn)
    conn.close()
    return df


tables_df = show_tables()
print("Tables in the database:")
print(tables_df)

# To show columns of a specific table 
columns_df = show_columns('topics')
print("\nColumns in 'topics' table:")
print(columns_df)

# To preview the first few rows of a table 
preview_df = preview_table('topics')
print("\nPreview of 'topics' table:")
print(preview_df)
# Out:
# Tables in the database:
#              table_name
# 0                topics
# 1                 items
# 2         market_images
# 3          marketplaces
# 4   marketplaces_status
# 5                 posts
# 6          forum_images
# 7                 users
# 8        topics_history
# 9         users_history
# 10               forums
# 11            items_cve
# 12        items_history
# 13            posts_cve
# 14        posts_history
# 15      vendors_history
# 16        forums_status
# 17              vendors
#
# Columns in 'topics' table:
#               column_name                 data_type
# 0   classification2_topic          double precision
# 1                forum_id                   integer
# 2               author_id                   integer
# 3    classification_topic          double precision
# 4                   label                       bit
# 5                topic_id                   integer
# 6             views_topic                   integer
# 7             posts_topic                   integer
# 8         dateadded_topic  timestamp with time zone
# 9      dateinserted_topic  timestamp with time zone
# 10            title_topic         character varying
# 11            board_topic         character varying
# 12             href_topic         character varying
#
# Preview of 'topics' table:
#    topic_id  forum_id  author_id  \
# 0      1266         2      11781
# 1        13         1          9
# 2        16         1         11
# 3        17         1         12
# 4        20         1         14
# 5        22         1         15
# 6        23         1         16
# 7        24         1         17
# 8        25         1         18
# 9        28         1         20
#
#                                          title_topic      board_topic  \
# 0                        🔰PYTHON BTC Wallet Cracker🔰          Hacking
# 1  HIRE PROFESSIONAL ETHICAL HACKER WITH SKILLS O...  Hacked Database
# 2   Easy and Fast Illegal and Anonymous Money Online  Hacked Database
# 3           Gun Store : Shop for and Buy Guns Online  Hacked Database
# 4  We provide services for the production of all ...  Hacked Database
# 5  We provide services for the production of all ...  Hacked Database
# 6            All Skybound customer data - @Sanggiero  Hacked Database
# 7  Stuck at Carding ? Having Any trouble ? Start ...  Hacked Database
# 8  WORK WITH THE WORLD BEST TEAM OF HACKERS(Teleg...  Hacked Database
# 9  Get List For WinPot malwarecutlet maker Yoda a...  Hacked Database
#
#    views_topic  posts_topic  \
# 0         2000          271
# 1         1276            1
# 2         1061            0
# 3         1019            0
# 4          701            0
# 5          686            0
# 6          710            0
# 7          710            0
# 8          679            0
# 9          578            0
#
#                                           href_topic  \
# 0  /threads/%F0%9F%94%B0python-btc-wallet-cracker...
# 1                              /viewtopic.php?t=1376
# 2                              /viewtopic.php?t=1614
# 3                              /viewtopic.php?t=1541
# 4                              /viewtopic.php?t=1503
# 5                              /viewtopic.php?t=1469
# 6                              /viewtopic.php?t=1462
# 7                              /viewtopic.php?t=1456
# 8                              /viewtopic.php?t=1434
# 9                              /viewtopic.php?t=1402
#
#             dateadded_topic         dateinserted_topic  classification_topic  \
# 0 2020-06-01 08:38:35+00:00  2023-10-06 00:00:00-07:00          1.751276e-05
# 1 2023-05-27 18:25:38+00:00  2023-11-10 00:00:00-08:00          1.015246e-13
# 2 2023-05-25 06:01:25+00:00  2023-11-10 00:00:00-08:00          1.020382e-14
# 3 2023-05-20 11:03:39+00:00  2023-11-10 00:00:00-08:00          3.355375e-15
# 4 2023-05-17 19:56:45+00:00  2023-11-10 00:00:00-08:00          6.143108e-15
# 5 2023-05-11 04:46:51+00:00  2023-11-10 00:00:00-08:00          2.895537e-13
# 6 2023-05-07 17:38:59+00:00  2023-11-10 00:00:00-08:00          1.109663e-02
# 7 2023-05-06 17:00:34+00:00  2023-11-10 00:00:00-08:00          1.352575e-05
# 8 2023-05-04 07:08:33+00:00  2023-11-10 00:00:00-08:00          5.952882e-15
# 9 2023-04-30 05:33:53+00:00  2023-11-10 00:00:00-08:00          6.996329e-01
#
#   label  classification2_topic
# 0  None               0.985156
# 1  None               0.989179
# 2  None               0.163280
# 3  None               0.150691
# 4  None               0.095242
# 5  None               0.201588
# 6  None               0.752069
# 7  None               0.954648
# 8  None               0.984428
# 9  None               0.772066
